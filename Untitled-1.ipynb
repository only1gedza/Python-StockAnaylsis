# %%
#Stock Analysis using Jupyter in Vscode

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %pip install yfinance
import yfinance as yf
# %matplotlib inline
# Out:
# Requirement already satisfied: yfinance in c:\users\gedza\anaconda3\lib\site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\gedza\anaconda3\lib\site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\gedza\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\gedza\anaconda3\lib\site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\gedza\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in c:\users\gedza\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gedza\appdata\roaming\python\python38\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gedza\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\gedza\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gedza\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gedza\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gedza\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gedza\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Get start and End Stock data for Tesla, Google and Amazon
start = "2014-01-01"
end = '2022-1-01'
TSLA = yf.download('TSLA',start,end)
AMZ = yf.download('AMZN',start,end)
GOOG = yf.download('GOOGL',start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#Plot stocks graph
TSLA['Open'].plot(label = 'TSLA', figsize = (13,5))
AMZ['Open'].plot(label = "AMZ")
GOOG['Open'].plot(label = 'GOOG')
plt.title('Stock Prices of TSLA, AMZ and GOOG')
plt.legend()
# Out:
# Text(0.5, 1.0, 'Stock Prices of TSLA, AMZ and GOOG')

# %%
TSLA['Volume'].plot(label = 'TSLA', figsize = (15,7))
AMZ['Volume'].plot(label = "AMZ")
GOOG['Volume'].plot(label = 'GOOG')
plt.title('Volume of Stock traded')
plt.legend()

# %%
#Market Capitalisation
TSLA['MarktCap'] = TSLA['Open'] * TSLA['Volume']
AMZ['MarktCap'] = AMZ['Open'] * AMZ['Volume']
GOOG['MarktCap'] = GOOG['Open'] * GOOG['Volume']
TSLA['MarktCap'].plot(label = 'TSLA', figsize = (15,7))
AMZ['MarktCap'].plot(label = 'AMZ')
GOOG['MarktCap'].plot(label = 'GOOG')
plt.title('Market Cap')
plt.legend()
